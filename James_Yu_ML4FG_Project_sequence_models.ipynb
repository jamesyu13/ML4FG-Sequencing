# %% [markdown]
# # Name for Project

# %%
uni = "jyy2140"
name = "James Yu"

# %% [markdown]
# # Hidden Markov Models
#
# First we'll set up some helper functions.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(2)

def norm(x):
    '''
    Return the input normalized to have sum of 1.
    '''
    return(x/x.sum())

def row_norm(x):
    '''
    Return the input normalized so that each row sums to 1.
    '''
    return x / x.sum(1, keepdims=True)

# %% [markdown]
# ## Sampling from the HMM
#
# An HMM is a `generative process` which means that given parameters T, E and gamma0 we can sample imaginary data from the model. Here's a function to just that, generating a sequence y of length S (as well as the underlying hidden states x).

# %%
def sampleHMM(gamma0, T, E, S):
    '''
Sample from the HMM

Parameters
----------
gamma0
    initial distribution over states of the HMM
T
    transition matrix of size K x K
E
    emission matrix size K x L
S
    sequence length

Returns
-------
x
    Vector of hidden states
y
    Vector of observations
    '''
    K = gamma0.size
    L = E.shape[1]
    x = np.zeros(S, dtype = np.int32)
    y = np.zeros(S, dtype = np.int32)
    x[0] = np.random.choice(K, p=gamma0)
    y[0] = np.random.choice(L, p=E[x[0], :])
    for t in range(1,S):
        x[t] = np.random.choice(K, p = T[x[t-1], :])
        y[t] = np.random.choice(L, p = E[x[t], :])
    return (x,y)

# %% [markdown]
# Let's make a toy 2-state HMM and sample from it.

# %%
gamma0_true = np.array([0., 1.]) # start in state 1 (rather than 0)
T_true = np.array([[0.8, 0.2], [0.1, 0.9]]) # usually stay in the same state, a "sticky" HMM
E_true = np.array([[0.4, 0.4, 0.1, 0.1], [0.1, 0.1, 0.4, 0.4]])

np.random.seed(3)
x,y = sampleHMM(gamma0_true, T_true, E_true, S = 100)

plt.figure(figsize=(14,4))
plt.plot(x, "o")
plt.title("Hidden state x")

plt.figure(figsize=(14,4))
plt.plot(y, "o")
plt.title("Observations y")
# Out:
# Text(0.5, 1.0, 'Observations y')

# %% [markdown]
# Notice that the the Markov chain of hidden states tends to stay in the same state for a while, and that in state 1 we get more 2s and 3s in y.
#
# ## Forwards-backwards
#
# Now let's see what the forward pass might look like.
#
#
# First we implement the forward pass. We first initialize
# $$ f_{1:} = \text{norm}( \gamma_0 \cdot E_{:y_{1}} ) $$
# where $f = \text{norm}(f_*)$ implies
# $$ f_i = \frac{ f^*_i }{ \sum_{i'} f^*_{i'} } $$
# Then at each time point $t$
# $$ r_{ti} = \sum_j T_{ji} f_{(t-1)j} $$
# $$ f^*_{ti} = r_{ti} E_{iy_t} $$
# $$ f_{ti} = \frac{ f^*_{ti} }{ \sum_{i'} f^*_{ti'} } $$
#
#
# We can write the per time point updates above for $r$ and $f$ in matrix notation. Consider $r$ and $f$ as matrices, use $\cdot$ to denote elementwise multiplication and make use of the `norm` function defined above.
#
# $$ r_{t:} = f_{t-1} T$$
# $$ f_{t:} = \text{norm}(r_t \cdot E_{:y_t})$$

# %%
def forwards(y, gamma0, T, E):
    '''
Forward pass of forwards-backwards algorithm.

Parameters
----------
y
    vector of observations, assumed to be in range(E.shape[1])
gamma0
    initial distribution as vector of size K
T
    transition matrix of size K x K
E
    emission matrix size K x L
Returns
-------
f
    forward "messages" f[t,k] = P(x[t]=k | y[0:t]=y[0:t]) for 0<=k<K and 0<=t<S
  '''
    S = y.size
    K = T.shape[0]

    #f [S x K]
    f = np.zeros((S, K))

    f[0,:]  = gamma0 * E[:,y[0]]


    for t in range(1,S):
        rt = norm(f[t-1,:] @ T)
        f[t,:] = norm(rt * E[:,y[t]])

    return f

# %% [markdown]
# Now we implement the equivalent backwards pass. The updates in matrix notation, for $t=\{S-1,\cdots,1\}$ are:
# $$ q_{t:} = (E_{:y_{t+1}})' \cdot b_{t+1:} $$
# $$ b_{t:} = (T q'_{t:})' $$ (by convention no `norm` is used).
# Note $b_{S:} = [1, ..., 1]$, $\cdot$ implies elementwise multiplication and $q'$ denotes the transpose.
#
# Next we write the updates in NON matrix notation:
# $$ q_{ti} = E_{i, y_{t+1}} \cdot b_{t+1,i} $$
# $$ b_{ti} = \sum_{j=1}^{K} T_{i,j} \cdot q_{t,j} $$

# %%
def backwards(y, T, E):
    '''
    Backwards pass of forwards-backwards algorithm.

    Parameters
    ----------
    y
        vector of observations, assumed to be in range(E.shape[1])
    T
        transition matrix of size K x K
    E
        emission matrix size K x L

    Returns
    -------
    b
        Backward "messages" b[t,k] = [P(y[t+1:n] | X[t]=k) for 0<=k<K and 1<=t<S
    '''
    S = y.size
    K = T.shape[0]

    # Initialize b
    b = np.ones((S, K))
    q = np.zeros((S,K))

    # Loop backwards from S-2 to 0
    for t in range(S-2,0,-1):
        for i in range(K):
            q[t,i] = E[i,y[t+1]] * b[t+1,i]
        for i in range(K):
            b[t,i] = np.sum([q[t,j] * T[i,j] for j in range(K)])
    return b

# %% [markdown]
# Armed with the forwards and backwards functions we can now get the posterior over X given the observations we just generated, Y. Here we're cheating: since we generated the data we know what the true parameters gamma0, T and E are so we'll use those in forwards-backwards.

# %%
def forwards_backwards( y, gamma0, T, E ):
    f = forwards(y, gamma0, T, E) # result is S x K
    b = backwards(y, T, E)
    gamma = row_norm( f * b ) # get the posterior gamma[t,k] = P(X[t]=k | y[0:S])
    return gamma, f, b

gamma, f, b = forwards_backwards(y, gamma0_true, T_true, E_true )

assert( abs(gamma[-1,1] - 0.6397375803142555) < 1e-10  )
assert( abs(gamma[-50,1] - 0.9566209571811642) < 1e-10  )

# %% [markdown]
#  We can then look how well our posterior over X agrees with the true X, since we also have that from the simulation.

# %%
plt.figure(figsize=(14,4))
plt.plot(gamma[:,1], "-o") # P(X[t] = 1 | Y[0:t])
plt.plot(x, "o")

# %% [markdown]
# You can see that the posterior tends towards the `correct` hidden state, and in fact gets it right 86% of the time:

# %%
np.mean((gamma[:,1] > .5) == (x==1))
# Out:
# 0.86

# %% [markdown]
# There is some uncertainty because either state can generate any four of the observation values, just with somewhat different probabilities.
#
# ## Baum-Welch
#
# Below we provide an implementation of Baum-Welch with the E-step (forwards backwards) and the M-step implemented for T but not for E.
#
#
# We start to implement the M-step for the emission matrix E. We are given:
# $$ E^*_{ij} = \sum_{t=1}^S \gamma_{ti} 1[ y_t = j ] $$
# $$ E_{i:} = \text{norm}(E^*_{i:}) $$
#
#
# The first step is implementing the $E$ update without looping over $t$. We  make the S x L matrix Y with elements $Y_{tj} = 1[ y_t = j ]$.

# %%
def baum_welch(y, gamma0, tol=1e-4, maxIt = 100):
    '''
    Compute maximum likehood estimate using Expectation-Maximization

    Parameters
    ----------
    y
        vector of observations
    gamma0
        initial distribution of the hidden chain
    tol
        tolerance for the stopping criterion
    maxIt
        maximal number of iterations

    Returns
    -------
    T
        K x K estimate of the transition matrix T[i,j] = P(X[t]=j | X[t-1]=i)
    E
        K x L estimate of the emission matrix E[i,j] = P(Y[t]=j | X[t]=i)
  '''
    K = gamma0.size
    L = 1+max(y)
    S = y.size
    Y = np.zeros([S, L])
    Y[range(S), np.int_(y)] = 1

    # randomly initialize T, E
    T = row_norm( np.random.rand(K, K).astype(np.float32) )
    E = row_norm( np.random.rand(K, L).astype(np.float32) )

    it = 0
    oldT = T
    oldE = E + tol +1

    while (np.abs(oldT-T).sum() + np.abs(oldE-E).sum() > tol) and (it<maxIt):
        it += 1

        oldT = T.copy()
        oldE = E.copy()

        # E-step
        gamma, f, b = forwards_backwards(y, gamma0, T, E)

        # M-step
        Tstar = np.zeros((K,K))
        for t in range(S-1):
            Tstar += norm( T * np.outer( f[t,:], E[:,y[t+1]] * b[t+1,:] ) )
        T = row_norm(Tstar)

        # E update
        gamma_matrix = np.tile(gamma[:, :, np.newaxis], (1, 1, L))
        Estar = np.sum(gamma_matrix * Y[:, np.newaxis, :], axis=0)
        E = row_norm(Estar)


    return (T, E)

# %% [markdown]
# Now we've implemented Baum-Welch let's see how we do recovering the true E and T.

# %%
np.random.seed(2)

T_mle, E_mle = baum_welch(y, gamma0_true)

print("True T:\n", T_true)
print("Infered T:\n", T_mle)
print("Mean absolute error in T: %.3f" % np.mean(np.abs(T_true - T_mle)))

print("True E:\n", E_true)
print("Infered E:\n", E_mle )
print("Mean absolute error in E: %.3f" % np.mean(np.abs(E_true - E_mle)))

assert( abs(E_mle[0,0] - 0.19228533549712362) < 1e-10 )
# Out:
# True T:
#  [[0.8 0.2]
#  [0.1 0.9]]
# Infered T:
#  [[0.91 0.09]
#  [0.08 0.92]]
# Mean absolute error in T: 0.066
# True E:
#  [[0.4 0.4 0.1 0.1]
#  [0.1 0.1 0.4 0.4]]
# Infered E:
#  [[1.92e-01 3.87e-01 2.20e-01 2.01e-01]
#  [2.44e-01 4.46e-13 4.44e-01 3.11e-01]]
# Mean absolute error in E: 0.102

# %% [markdown]
# These estimates are clearly better than random, but there is some overfitting going on: note in particular the almost 0 probability of generating the 2nd observed value from state 1, which we know should be 0.1. Try a few other random seeds (this will change the random initialization of E and T) to see that most are worse than the one I picked!
#
# In practice for EM (as well as other optimization approaches that get stuck in local optima) we would do multiple random restarts (e.g. 10 - 50 typically) and somehow score which are best. While we won't cover it here, for HMMs it is possible to calculate the marginal likelihood $P(Y|E,T)$ as part of the forward-backwards algorithm, which can then be used as such as score.
#
# Let's see how well we did at recovering x:

# %%
gamma, f, b = forwards_backwards(y, gamma0_true, T_mle, E_mle)
plt.figure(figsize=(14,4))
plt.plot(gamma[:,1], "-o") # P(X[t] = 1 | Y[0:t])
plt.plot(x, "o")

# %% [markdown]
# `The recovered x is "better than random", in that considering this as a classifier, we're getting the right state 69% of the time:

# %%
np.mean((gamma[:,1] > .5) == (x==1))
# Out:
# 0.69

# %% [markdown]
# However there are many regions where the wrong state is inferred because of the errors in the recovered E matrix.
#
# One easy solution to this overfitting is to add a pseudocount of 1 to all the values in Estar and Tstar. You can interpret this as putting a Dirichlet(2,...,2) prior on each row of E and T, or using a Dirichlet(1,...,1) prior on those rows but updating to the posterior expectation rather than the maximum likelihood estimate (a bit more like variational Bayes).
#
# Copying our code for `baum_welch` but add 1 to Estar and Tstar just before normalizing with row_norm.

# %%
def baum_welch_with_pseudocount(y, gamma0, tol=1e-4, maxIt=100):
    '''
    Compute maximum likehood estimate using Expectation-Maximization

    Parameters
    ----------
    y
        vector of observations
    gamma0
        initial distribution of the hidden chain
    tol
        tolerance for the stopping criterion
    maxIt
        maximal number of iterations

    Returns
    -------
    T
        K x K estimate of the transition matrix T[i,j] = P(X[t]=j | X[t-1]=i)
    E
        K x L estimate of the emission matrix E[i,j] = P(Y[t]=j | X[t]=i)
    '''
    K = gamma0.size
    L = 1 + max(y)
    S = y.size
    Y = np.zeros([S, L])
    Y[range(S), np.int_(y)] = 1

    # randomly initialize T, E
    T = row_norm(np.random.rand(K, K).astype(np.float32))
    E = row_norm(np.random.rand(K, L).astype(np.float32))

    it = 0
    oldT = T
    oldE = E + tol + 1

    while (np.abs(oldT - T).sum() + np.abs(oldE - E).sum() > tol) and (it < maxIt):
        it += 1

        oldT = T.copy()
        oldE = E.copy()

        # E-step
        gamma, f, b = forwards_backwards(y, gamma0, T, E)

        # M-step for T
        Tstar = np.zeros((K, K))
        for t in range(S - 1):
            Tstar += norm(T * np.outer(f[t, :], E[:, y[t + 1]] * b[t + 1, :]))
        T = row_norm(Tstar + 1)

        # M-step for E with pseudocount
        gamma_matrix = np.tile(gamma[:, :, np.newaxis], (1, 1, L))
        Estar = np.sum(gamma_matrix * Y[:, np.newaxis, :], axis=0)
        E = row_norm(Estar + 1)

    return T, E

# %%
np.random.seed(2)

T_mle, E_mle = baum_welch_with_pseudocount(y, gamma0_true)

assert( abs(E_mle[0,0] - 0.298322068734388) < 1e-10 )

print("True T:\n", T_true)
print("Infered T:\n", T_mle)
print("Mean absolute error in T: %.3f" % np.mean(np.abs(T_true - T_mle)))

print("True E:\n", E_true)
print("Infered E:\n", E_mle )
print("Mean absolute error in E: %.3f" % np.mean(np.abs(E_true - E_mle)))
# Out:
# True T:
#  [[0.8 0.2]
#  [0.1 0.9]]
# Infered T:
#  [[0.76 0.24]
#  [0.11 0.89]]
# Mean absolute error in T: 0.026
# True E:
#  [[0.4 0.4 0.1 0.1]
#  [0.1 0.1 0.4 0.4]]
# Infered E:
#  [[0.3  0.43 0.16 0.11]
#  [0.19 0.07 0.41 0.33]]
# Mean absolute error in E: 0.050

# %% [markdown]
# These estimates are a lot closer to the ground truth than without the pseudocounts. That will result in a better recovery of x too:

# %%
gamma, f, b = forwards_backwards(y, gamma0_true, T_mle, E_mle)
plt.figure(figsize=(14,4))
plt.plot(gamma[:,1], "-o") # P(X[t] = 1 | Y[0:t])
plt.plot(x, "o")

# %% [markdown]
# Now we get the correct state 85% of the time! (Remember with the true E and T we only got 86%!)

# %%
np.mean((gamma[:,1] > .5) == (x==1))
# Out:
# 0.85

# %% [markdown]
# # Real data: single cell bisulphite sequencing
#
# Now it's time to run on some real data. We'll be looking at the single cell Bisulphite sequencing ("scBS-seq") data from the DeepCpG paper.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

scBSseq = np.load("/content/drive/MyDrive/ML4fungen/Assignment 3/scBSseq.npz") # might need to change this

meth_mat = scBSseq["meth_mat"] # positions x cells matrix of counts of methylated CpGs
unmeth_mat = scBSseq["unmeth_mat"] # positions x cells matrix of counts of unmethylated CpGs (i.e. C got converted to T)
positions = scBSseq["positions"] # genomic position of each CpG
chroms = scBSseq["chroms"] # chromomsome of each CpG
cell_names = scBSseq["cell_names"] # cell type and an arbitrary ID
cell_names
# Out:
# array(['2i_1', '2i_10', '2i_11', '2i_12', '2i_2', '2i_3', '2i_4', '2i_5',
#        '2i_6', '2i_7', '2i_8', '2i_9', 'MII_1', 'MII_10', 'MII_11',
#        'MII_12', 'MII_2', 'MII_3', 'MII_4', 'MII_5', 'MII_6', 'MII_7',
#        'MII_8', 'MII_9', 'Ser1', 'Ser10', 'Ser11', 'Ser12', 'Ser13',
#        'Ser14', 'Ser15', 'Ser16', 'Ser17', 'Ser18', 'Ser19', 'Ser2',
#        'Ser20', 'Ser3', 'Ser4', 'Ser5', 'Ser6', 'Ser7', 'Ser8', 'Ser9'],
#       dtype='<U6')

# %% [markdown]
# ## Exploratory data analysis
#
# It's always a good idea to do some exploratory data analysis (EDA) on a new dataset before trying out our fancy new ML model.
#
# Especially in single-cell data it's important to get a sense how sparse the data is. We filtered this data for CpG positions with reads in at least 10 cells but the data is still pretty sparse:

# %%
import matplotlib.pyplot as plt

total_counts = meth_mat + unmeth_mat
ncells_with_reads = (total_counts > 0).sum(1)
plt.hist(ncells_with_reads, np.arange(-.5,30.5) )
np.mean(total_counts > 0)
# Out:
# 0.2968330165185542

# %% [markdown]
# So about 30% of entries have data.
#
# Principal components analysis (PCA) is an excellent tool for EDA on high dimensional data. It's a little challenging to apply here because there's so much missingness: to handle that we'll add a small pseudocount and only look at CpGs where there is data for at least 25 cells (you can see from the histogram above this is a small proportion!)

# %%
pseudocount = 0.25
meth_level = ( meth_mat + pseudocount) / (total_counts + 2 * pseudocount)
meth_level = meth_level[ncells_with_reads >= 25,:] # only consider CpG positions with reads in 25 (out of 44) cells

meth_level_centered = meth_level - meth_level.mean(1, keepdims=True) # remove the per position mean

# numpy implementation uses too much memory
# u,s,vh = np.linalg.svd(meth_level_centered, full_matrices=True) # use SVD to do PCA (quite cpu/memory intensive)
import torch
torch.manual_seed(0) # torch uses a randomized algorithm so set the seed for reproducibility
usvh = torch.pca_lowrank( torch.tensor(meth_level_centered).to("cuda"), q=44, center=False, niter=10)
u,s,vh = [ g.cpu().numpy() for g in usvh ]
vh = vh.transpose()

plt.plot(100 * s**2 / np.sum(s**2), "o-")
plt.ylabel("Percent variance explained")
plt.xlabel("PC")
# Out:
# Text(0.5, 0, 'PC')

# %% [markdown]
# The single values here tell us how much variance is represented by each PC. As is common with high dimensional data we see a lot of signal in the first few PCs.
#
# Plotting the first two PCs we see that cell type drives much of the variation in the data - the cells separate by cell type for the most part. 2i and Ser samples look distinct but more similar to one another than to MII, which is expected given that they are the same cell type just grown in different conditions.

# %%
vh.shape
# Out:
# (44, 44)

# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame(
    { "pc1" : vh[0,:],
      "pc2" : vh[1,:],
      "cell_type" : [ cn[:2] for cn in cell_names ] } )

_ = sns.pairplot(x_vars = ["pc1"], y_vars = ["pc2"], hue = "cell_type", data = df, height=6 )

# %% [markdown]
# ## Applying the HMM
#
# PCA isn't a great model for this data for two reasons:
# 1. It can't handle missingness (or count based likelihoods) naturally.
# 2. It ignores the sequential nature of the data.
#
# So let's try using an HMM. The data at each CpG position is a vector of methylated and unmethylated counts, which it is natural to model using a binomial likelihood. The emission parameter $E_{ij} \in [0,1]$ is the probability of cell $j$ having a methylated CpG if the hidden state is $i$.
#
# First we'll rewrite the forwards-backwards algorithm to be agnostic to the form of the likelihood.
#
# We write new forward backwards updates that take a matrix
# $O_{kt} = P(Y_t | X_t = k) $ instead of Y and E. For the standard HMM
# $O_{kt} = E_{kY_t}$.
#
# We'll be using longer sequences where the standard implementation of the backwards update can end up being 0 to machine precision. To avoid this, we wrap our b[t,:] calculation in a `norm` call (at every $t$ step, not just at the end!). We only care about the values of b[t,:] up to a multiplicative constant so this won't change anything.

# %%
import numpy as np

def forwards_generic(gamma0, T, O):
    '''
    Forward pass of forwards-backwards algorithm.

    Parameters
    ----------
    gamma0
        initial distribution as vector of size K
    T
        transition matrix of size K x K
    O
        likelihood terms for observations: P(Y_t | X_t = k) K x S

    Returns
    -------
    f
        S x K matrix: forward "messages" f[t,k] = P(x[t]=k | y[0:t]=y[0:t]) for 0<=k<K and 0<=t<S
    '''
    S = O.shape[1]
    K = T.shape[0]

    # Initialize f
    f = np.zeros((S, K))

    # Calculate f[0,:]
    f[0, :] = gamma0 * O[:, 0]

    # Normalize to prevent underflow
    f[0, :] /= np.sum(f[0, :])

    # Loop forward to calculate f[1:,:]
    for t in range(1, S):
        rt = np.dot(f[t - 1, :], T)
        f[t, :] = rt * O[:, t]

        # Normalize to prevent underflow
        f[t, :] /= np.sum(f[t, :])

    return f


def backwards_generic(T, O):
    '''
    Backwards pass of forwards-backwards algorithm.

    Parameters
    ----------
    T
        transition matrix of size K x K
    O
        likelihood terms for observations: P(Y_t | X_t = k) K x S

    Returns
    -------
    b
        S x K matrix: Backward "messages" b[t,k] = [P(y[t+1:n] | X[t]=k) for 0<=k<K and 1<=t<S
    '''
    S = O.shape[1]
    K = T.shape[0]

    # Initialize backward messages
    b = np.ones((S, K))
    q = np.zeros((S, K))

    # Loop backwards from S-2 to 0
    for t in range(S - 2, -1, -1):
        for i in range(K):
            q[t, i] = O[i, t + 1] * b[t + 1, i]
        for i in range(K):
            b[t, i] = np.sum([q[t, j] * T[i, j] for j in range(K)])

        # Normalize at each time step
        b[t, :] = norm(b[t, :])

    return b


def forwards_backwards_generic(gamma0, T, O):
    '''
    Forwards-backwards algorithm.

    Parameters
    ----------
    gamma0
        initial distribution as a vector of size K
    T
        transition matrix of size K x K
    O
        likelihood terms for observations: P(Y_t | X_t = k) K x S

    Returns
    -------
    gamma
        S x K matrix: posterior gamma[t,k] = P(X[t]=k | y[0:S])
    f
        S x K matrix: forward "messages" f[t,k] = P(x[t]=k | y[0:t]=y[0:t]) for 0<=k<K and 0<=t<S
    b
        S x K matrix: Backward "messages" b[t,k] = [P(y[t+1:n] | X[t]=k) for 0<=k<K and 1<=t<S
    '''
    f = forwards_generic(gamma0, T, O)
    b = backwards_generic(T, O)
    gamma = row_norm(f * b)
    return gamma, f, b

def forwards_backwards_check(y, gamma0, T, E):
    S = len(y)
    K = gamma0.shape[0]

    # Calculate O from E and y
    O = np.zeros((K, S))
    for t in range(S):
        O[:, t] = E[:, y[t]]

    gamma, f, b = forwards_backwards_generic(gamma0, T, O)
    return gamma, f, b

gamma, f, b = forwards_backwards( y, gamma0_true, T_true, E_true )
gamma_check, f, b = forwards_backwards_check( y, gamma0_true, T_true, E_true )
assert( abs(gamma[-1,1] - gamma_check[-1,1]) < 1e-10  )

# %% [markdown]
# ## Binomial HMM
#
# Now we're ready to make a version of forward-backwards for our binomial vectors. We want
# $$ O_{kt} = P(Y_t | X_t = k) = \prod_{n=1}^N P(Y_{tn} | X_t = k) $$
#
# The binomial likelihood for an individual cell is
# $$ P(Y_{tn} | X_t = k) = Bin( M_{tn} | M_{tn} + U_{tn}, E_{k n} ) = E_{k n}^{M_{tn}} (1-E_{k n})^{U_{tn}} $$
# where $M_{tn}$ and $U_{tn}$ are the methylated and unmethylated counts respectively and $E_{ij} = P(Y_{tj} = 1 | X_t = i )$ is a matrix of binomial probabilities. When multiplying probabilities together it's generally a good idea to work in log probability space, where multiplication corresponds to addition.
#
# NOTE: a convenient aspect of the binomial likelihood is that $M_{tn} + U_{tn} = 0$ corresponds to entry $tn$ being missing, so we don't have to do anything special to handle "missingness".
#
# Writing $\log O_{kt}$ in terms of $E$, $M$ and $U$:
# $$\log O_{kt} = \sum_{n=1}^{N}\left(M_{tn}\log E_{kn}+U_{tn}\log\left(1-E_{kn}\right)\right) $$
#
# Next we express this in matrix notation, where assuming the log function is applied elementwise:
# $$\log O = \log\left(E\right)M^{T}+\log\left(1-E\right)U^{T} $$
#
# Now we can implement the calculation in this function.

# %%
def forwards_backwards_binomial( meth_mat, unmeth_mat, gamma0, T, E ):
    logO = np.log(E) @ np.transpose(meth_mat) + np.log1p(-1*E) @ np.transpose(unmeth_mat)
    logO -= logO.max(0,keepdims=True) # not strictly necessary but more numerically stable
    O = np.exp(logO)

    gamma, f, b = forwards_backwards_generic(gamma0, T, O)
    return gamma, f, b, O

# %% [markdown]
# It is often useful for methods with local optima (like EM fitting of an HMM) to use some fast and/or analytic method to get a reasonable initialization. As well as hopefully finding a better optimum than random initialization, this makes the analysis reproducible without setting random seeds.
#
# One way to that here is using the PCA we've already done. The vh matrix is a PCs x L (cells) weight matrix analogous to the E matrix in our binomial model. We'll take the top K PCs of vh and rescale to get valid probabilities:

# %%
K = 10

E_init = vh[:K,:]
E_init -= E_init.min(1, keepdims=True)
E_init /= E_init.max(1, keepdims=True)
E_init = 0.8 * E_init + 0.1

# %% [markdown]
# For the transition matrix T we expect that the most likely transition is to stay in the same state (since we know neighboring CpGs have correlated methylation) so we'll just set T to have more weight on the diagonal:

# %%
T_init = row_norm(np.identity(K) + 1/K)

# %% [markdown]
# Now we can test our new forward-backwards algorithm on some of the "real" data. To keep things fast we'll just try this out on the first 30000 CpGs.

# %%
S = 30000 # np.sum(chroms=='1') # just run on chromosome 1

gamma0 = np.full(K,1/K)
gamma, f, b, O = forwards_backwards_binomial( meth_mat[:S,:], unmeth_mat[:S,:], gamma0, T_init, E_init )

assert( abs(gamma[-1,4] - 1.0168727093165696e-06) < 1e-10  )

# %% [markdown]
# ## Baum-Welch for the binomial HMM
#
# Now let's implement Baum-Welch so we can find good parameters E and T for the binomial HMM applied to the methylation data.
#
# We first derive the M-update for the emission matrix E.
#
# In the M step we try to optimize the expected log likelihood wrt whatever parameter (in this case E). The likelihood for an individual position and cell if we know $X_t=k$ is
# $$P(Y_{tn} | X_t = k) = Bin( M_{tn} | M_{tn} + U_{tn}, E_{k n} ) = E_{k n}^{M_{tn}} (1-E_{k n})^{U_{tn}} $$
# However, we don't know what state $X_t$ will be in so we can use the trick we used for the regular discrete likelihood HMM in class:
# $$ P(Y_{tn} | X_t) = \prod_k P(Y_{tn} | X_t = k)^{1[X_t = k]}$$
# where $1[.]$ is the indicator function and importantly $ \mathbb{E}_Q( 1[X_t = k]) = \gamma_{kt}$ where $\gamma$ comes from forward backwards.
#
# The complete likelihood is just
# $$ P(Y | X ) = \prod_{tn} P(Y_{tn} | X_t) $$
#
# Using the log of complete likelihood from above,
# $$ L=\sum_{tn}^{ }\sum_{k}^{ }\gamma_{kt}\left(M_{tn}\log E_{kn}+U_{tn}\log\left(1-E_{kn}\right)\right) $$
#
# $$ \frac{dL}{dE_{kn}}=\sum_{tn}^{ }\frac{\gamma_{kt}}{K_{kn}}M_{tn}-\frac{\gamma_{kt}}{1-E_{kn}}U_{tn}=0 $$
#
# $$ \sum_{tn}^{ }\gamma_{kt}M_{tn}=E_{kn}\sum_{tn}^{ }\gamma_{kt}\left(M_{tn}+U_{tn}\right) $$
#
# $$ E_{kn}=\frac{\sum_{tn}^{ }\gamma_{kt}M_{tn}}{\sum_{tn}^{ }\gamma_{kt}\left(M_{tn}+U_{tn}\right)} $$
#
# In matrix notation with a pseudocount of 1:
#
# $$ E_{kn}=\sum_{t}^{S}\sum_{n}^{L}\frac{\left(M_{tn}+1\right)}{\gamma_{kt}\left(M_{tn}+U_{tn}\right)+2} $$
#
# Implementing the M-update for the emission matrix in the code below:

# %%
def baum_welch_binomial(meth_mat, unmeth_mat, gamma0, E_init = None, T_init = None, tol=1e-4, maxIt = 100):
    '''
    Compute maximum likehood estimate using Expectation-Maximization

    Parameters
    ----------
    meth_mat
        S x L matrix of methylated counts
    unmeth_mat
        S x L matrix of unmethylated counts
    gamma0
        initial distribution of the hidden chain
    E_init
        Optional initialization of emission matrix E.
    T_init
        Optional initialization of transition matrix T.
    tol
        tolerance for the stopping criterion
    maxIt
        maximal number of iterations

    Returns
    -------
    T
        K x K estimate of the transition matrix T[i,j] = P(X[t]=j | X[t-1]=i)
    E
        K x L estimate of the emission matrix E[i,j], the binomial probability of methylation in cell j, given X[t]=i.
  '''
    K = gamma0.size
    L = meth_mat.shape[1]
    S = meth_mat.shape[0]

    # randomly initialize T, E
    T = row_norm( np.random.rand(K, K).astype(np.float32) ) if (T_init is None) else T_init
    E = 0.1 + 0.8 * np.random.rand(K,L) if (E_init is None) else E_init # don't put values too close to 0 or 1

    it = 0

    param_change = np.inf

    while (param_change > tol) and (it<maxIt):
        it += 1
        print("Iteration: %i Param change: %.3g" % (it, param_change))
        oldT = T.copy()
        oldE = E.copy()

        # E-step
        gamma, f, b, O = forwards_backwards_binomial(meth_mat, unmeth_mat, gamma0, T, E )
        assert(not np.any(np.isnan(gamma)))

        # M-step
        Tstar = np.zeros((K,K))
        for t in range(S-1):
            Tstar += norm( T * np.outer( f[t,:], O[:,t+1] * b[t+1,:] ) )
        T = row_norm(Tstar)

        # M-step update for E

        E_numerator = gamma.T @ meth_mat +1
        E_denomenator = gamma.T @ (meth_mat + unmeth_mat) + 2  # Pseudocount of 2 (Beta(2,2) prior)

        E = E_numerator / E_denomenator

        assert(not np.any(np.isnan(E)))

        #param_change = np.abs(oldT-T).sum() + np.abs(oldE-E).sum()
        param_change = max( np.abs(oldT-T).max() , np.abs(oldE-E).max() )

    return (T, E, gamma)

# %% [markdown]
# Alright, let's run it! We'll train on the first 30000 positions.
#
# Because this is "real" data we can't check whether our estimates of T and E against against ground truth. One approach to assessing our model and parameters is prediction of held out data, just like we would for a supervised model. In this case we'll "hold out" the counts for entries with coverage > 1  (about 13% of entries) and if we can impute them.

# %%
test_meth = meth_mat[:S, :]
test_unmeth = unmeth_mat[:S, :]
test_total = test_meth + test_unmeth
to_mask = test_total >= 2 # often you would use a random set of entries
print(to_mask.mean()) # how many entries are we testing on?
test_meth_masked = test_meth.copy()
test_meth_masked[to_mask] = 0
test_unmeth_masked = test_unmeth.copy()
test_unmeth_masked[to_mask] = 0

T,E,gamma = baum_welch_binomial( test_meth_masked, test_unmeth_masked, gamma0, E_init = E_init, T_init = T_init, tol = 0.01 )
# Out:
# 0.13284242424242423
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 40 Param change: 0.0167
# Iteration: 41 Param change: 0.0171
# Iteration: 42 Param change: 0.0173
# Iteration: 43 Param change: 0.0175
# Iteration: 44 Param change: 0.0175
# Iteration: 45 Param change: 0.0169
# Iteration: 46 Param change: 0.0155
# Iteration: 47 Param change: 0.0136
# Iteration: 48 Param change: 0.0118
# Iteration: 49 Param change: 0.0108

# %% [markdown]
# We notice that the parameters initially change quite a bit then convergence slows down. This is expected behavior for coordinate descent(/ascent), the class of methods that includes EM. For a graphical explanation
# ![coordinateascent](https://upload.wikimedia.org/wikipedia/commons/e/e3/Coordinate_descent.svg)
#
#
# Let's take a look at the learnt transition matrix T:

# %%
plt.imshow(T,vmin=0, vmax=1)
plt.colorbar()
plt.ylabel("Hidden state")
plt.xlabel("x[t+1]")
_ = plt.ylabel("x[t]")

# %% [markdown]
# Mostly here the HMM stays in the same state, but various other transitions  have substantial mass too.
#
# We can also look at the emission matrix, which shows clear patterns of states that correspond to methylation shared across cells of a specific type.

# %%
plt.figure(figsize=(18,8))
plt.imshow(E, vmin=0, vmax=1)
_ = plt.xticks(np.arange(len(cell_names)), cell_names, rotation="vertical")
plt.colorbar()
plt.xlabel("Cell name")
_ = plt.ylabel("Hidden state")

# %% [markdown]
# Now we want to calculate $ P(Y_\text{missing} | Y_\text{observed}, E, T) $. We will do this by summing over the posterior gamma_test.
#
# We derive $ Z_{tj} = P(Y^\text{missing}_{t} =j | Y_\text{observed}, E, T) $ in terms of $E_{ij} = P(Y_{tj} = 1 | X_t = i )$ and $ \gamma_{ti} = P( X_t = i | Y_\text{observed} )$ by using basic probability rules.
#
# $$ P\left(Y_{t}^{miss}=j,\ X_{t}=i\left|Y_{obs},E,T\right|\right)=P\left(Y_{t}^{miss}=j\ \left|X_{t}=i,\ Y_{obs},\ E,\ T\right|\right)\ \cdot P\left(X_{t}=i\left|Y_{obs},\ E,\ T\right|\right)=\prod_{n=1}^{L}E_{ij}^{1\left[Y_{tn}=j\right]}\cdot\gamma_{ti} $$
# $$ Z_{tj} = \sum_{i}^{ }\prod_{n=1}^{L}E_{ij}^{1\left[Y_{tn}=j\right]}\cdot\gamma_{ti} $$
# $$ Z = \gamma E $$
#
#
# Now we implement our expression:

# %%
Z = gamma @ E
Y_obs = test_meth / test_total
correct_pred = (Y_obs[to_mask]>.5) == (Z[to_mask]>.5)
correct_pred.mean()
# Out:
# <ipython-input-48-006d2db032e5>:3: RuntimeWarning: invalid value encountered in divide
#   Y_obs = test_meth / test_total
# 0.878427391760573

# %% [markdown]
# This should be 0.88, pretty good considering how sparse the data is.
#
# Let's visualize some of our predictions:

# %%
(cpg_start,cpg_end) = (10232143, 10233428)

window = 20000

in_cpg = np.logical_and( chroms == "1" , np.logical_and( cpg_start - window < positions , positions < cpg_end + window ))

meth_mat[in_cpg,:]
unmeth_mat[in_cpg,:]

y = meth_mat[in_cpg,:] / ( unmeth_mat[in_cpg,:] + meth_mat[in_cpg,:] )

plt.figure(figsize=(16,8))
_ = plt.plot( positions[in_cpg], y[:,:12], "o")
_ = plt.plot( positions[in_cpg], Z[in_cpg[:S],:12], "-")
# Out:
# <ipython-input-64-1cf45f8cbbf3>:10: RuntimeWarning: invalid value encountered in divide
#   y = meth_mat[in_cpg,:] / ( unmeth_mat[in_cpg,:] + meth_mat[in_cpg,:] )

# %% [markdown]
# We can vary the number of hidden states from 1 to 10 and see how this impacts imputation accuracy and run time.

# %%
import time
import matplotlib.pyplot as plt
import numpy as np

# Define the range of hidden states to try
num_hidden_states_range = range(1, 11)

# Lists to store results
accuracy_list = []
run_time_list = []

for num_hidden_states in num_hidden_states_range:
    print(f"Number of Hidden States: {num_hidden_states}")

    # Train the model with the current number of hidden states
    start_time = time.time()
    T, E, gamma_test = baum_welch_binomial(test_meth_masked, test_unmeth_masked, gamma0, E_init=E_init, T_init=T_init, tol=0.01)
    end_time = time.time()

    # Calculate Z as the expected Y given the posterior over X
    Z = np.dot(gamma_test, E)

    # Calculate the observed methylation ratio
    Y_obs = test_meth / test_total

    # Check correctness of predictions
    correct_pred = (Y_obs[to_mask] > 0.5) == (Z[to_mask] > 0.5)

    # Calculate accuracy
    accuracy = correct_pred.mean()

    # Record results
    accuracy_list.append(accuracy)
    run_time_list.append(end_time - start_time)

# Plot results
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Accuracy as a bar chart
color = 'tab:blue'
ax1.set_xlabel("Number of Hidden States")
ax1.set_ylabel("Imputation Accuracy", color=color)
ax1.bar(num_hidden_states_range, accuracy_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for Run Time
ax2 = ax1.twinx()
color = 'tab:orange'
ax2.set_ylabel("Run Time (seconds)", color=color)
ax2.plot(num_hidden_states_range, run_time_list, marker='o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title("Imputation Accuracy and Run Time vs Number of Hidden States")
plt.show()
# Out:
# Number of Hidden States: 1
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 40 Param change: 0.0167
# Iteration: 41 Param change: 0.0171
# Iteration: 42 Param change: 0.0173
# Iteration: 43 Param change: 0.0175
# Iteration: 44 Param change: 0.0175
# Iteration: 45 Param change: 0.0169
# Iteration: 46 Param change: 0.0155
# Iteration: 47 Param change: 0.0136
# Iteration: 48 Param change: 0.0118
# Iteration: 49 Param change: 0.0108
# <ipython-input-48-1c4d4750f444>:24: RuntimeWarning: invalid value encountered in divide
#   Y_obs = test_meth / test_total
# Number of Hidden States: 2
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 40 Param change: 0.0167
# Iteration: 41 Param change: 0.0171
# Iteration: 42 Param change: 0.0173
# Iteration: 43 Param change: 0.0175
# Iteration: 44 Param change: 0.0175
# Iteration: 45 Param change: 0.0169
# Iteration: 46 Param change: 0.0155
# Iteration: 47 Param change: 0.0136
# Iteration: 48 Param change: 0.0118
# Iteration: 49 Param change: 0.0108
# Number of Hidden States: 3
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 40 Param change: 0.0167
# Iteration: 41 Param change: 0.0171
# Iteration: 42 Param change: 0.0173
# Iteration: 43 Param change: 0.0175
# Iteration: 44 Param change: 0.0175
# Iteration: 45 Param change: 0.0169
# Iteration: 46 Param change: 0.0155
# Iteration: 47 Param change: 0.0136
# Iteration: 48 Param change: 0.0118
# Iteration: 49 Param change: 0.0108
# Number of Hidden States: 4
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 40 Param change: 0.0167
# Iteration: 41 Param change: 0.0171
# Iteration: 42 Param change: 0.0173
# Iteration: 43 Param change: 0.0175
# Iteration: 44 Param change: 0.0175
# Iteration: 45 Param change: 0.0169
# Iteration: 46 Param change: 0.0155
# Iteration: 47 Param change: 0.0136
# Iteration: 48 Param change: 0.0118
# Iteration: 49 Param change: 0.0108
# Number of Hidden States: 5
# Iteration: 1 Param change: inf
# Iteration: 2 Param change: 0.763
# Iteration: 3 Param change: 0.256
# Iteration: 4 Param change: 0.177
# Iteration: 5 Param change: 0.299
# Iteration: 6 Param change: 0.184
# Iteration: 7 Param change: 0.0812
# Iteration: 8 Param change: 0.0568
# Iteration: 9 Param change: 0.0465
# Iteration: 10 Param change: 0.0543
# Iteration: 11 Param change: 0.0539
# Iteration: 12 Param change: 0.0459
# Iteration: 13 Param change: 0.0348
# Iteration: 14 Param change: 0.0246
# Iteration: 15 Param change: 0.0198
# Iteration: 16 Param change: 0.0223
# Iteration: 17 Param change: 0.0253
# Iteration: 18 Param change: 0.0289
# Iteration: 19 Param change: 0.0334
# Iteration: 20 Param change: 0.0377
# Iteration: 21 Param change: 0.0392
# Iteration: 22 Param change: 0.0364
# Iteration: 23 Param change: 0.0314
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# Iteration: 24 Param change: 0.0266
# Iteration: 25 Param change: 0.0217
# Iteration: 26 Param change: 0.0177
# Iteration: 27 Param change: 0.0149
# Iteration: 28 Param change: 0.0141
# Iteration: 29 Param change: 0.0142
# Iteration: 30 Param change: 0.0138
# Iteration: 31 Param change: 0.0141
# Iteration: 32 Param change: 0.0156
# Iteration: 33 Param change: 0.0181
# Iteration: 34 Param change: 0.0211
# Iteration: 35 Param change: 0.0224
# Iteration: 36 Param change: 0.0217
# Iteration: 37 Param change: 0.0198
# Iteration: 38 Param change: 0.0179
# Iteration: 39 Param change: 0.0164
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-1c4d4750f444> in <cell line: 67>()
#      70     # Train the model hidden states
#      71     start_time = time.time()
# ---> 72     T, E, gamma_test = baum_welch_binomial(test_meth_masked, test_unmeth_masked, gamma0, E_init=E_init, T_init=T_init, tol=0.01)
#      73     end_time = time.time()
#      74
#
# <ipython-input-40-de2f6bd29616> in baum_welch_binomial(meth_mat, unmeth_mat, gamma0, E_init, T_init, tol, maxIt)
#      52         Tstar = np.zeros((K,K))
#      53         for t in range(S-1):
# ---> 54             Tstar += norm( T * np.outer( f[t,:], O[:,t+1] * b[t+1,:] ) )
#      55         T = row_norm(Tstar)
#      56
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in outer(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py in outer(a, b, out)
#     940     a = asarray(a)
#     941     b = asarray(b)
# --> 942     return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
#     943
#     944
#
# KeyboardInterrupt:

# %% [markdown]
# # RNNs
#
# In deep learning RNNs are often used to handle sequential data.
#
# ## Vanilla RNN
#
# First we'll build a single vanilla "cell", an individual computation unit for the RNN.

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt


class MyVanillaRNNCell(nn.Module):

    def __init__(self, input_size, hidden_size):
        super(MyVanillaRNNCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.linear = nn.Linear(input_size + hidden_size, hidden_size)

    def forward(self, x, h_in):
        """
        Forward computation.

        Parameters
        ----------
        x : torch.tensor
            [batch_size x input_size] input
        h_in : torch.tensor
            [batch_size x hidden_size] hidden state from previous time point

        Returns
        -------
        h_out : torch.tensor
            [batch_size x hidden_size] new hidden state
        """
        combined = torch.cat((x, h_in), 1) # concatenate in feature dimension
        h_out = torch.tanh( self.linear(combined) )
        return h_out

# %% [markdown]
# All this does is take the current input (x) and hidden state (h_in) and computes h_out according to $h_{out} = \tanh( W [x, h_in] + b )$. Although we don't see them explicitly in the code, the parameters $W$ and $b$ are stored in the `linear` layer.
#
# Now we can build an RNN layer as

# %%
class MyRNNLayer(nn.Module):

    def __init__(self, rnn_cell):
        super(MyRNNLayer, self).__init__()
        self.rnn_cell = rnn_cell

    @property
    def hidden_size(self):
        return self.rnn_cell.hidden_size

    @property
    def input_size(self):
        return self.rnn_cell.input_size

    def forward(self, x):
        (seq_len, batch_size, input_size) = x.shape
        hidden = torch.zeros(batch_size, self.hidden_size, device = x.device) # could be an input to the function
        output = torch.zeros(seq_len, batch_size, self.hidden_size, device = x.device)
        for i in range(seq_len): # iterate over sequence
            hidden = self.rnn_cell(x[i,:,:], hidden)
            output[i,:,:] = hidden
        return output

# %% [markdown]
# Let's try running our RNN with random input:

# %%
input_size = 4
hidden_size = 2
rnn_cell = MyVanillaRNNCell(input_size, hidden_size)
rnn = MyRNNLayer(rnn_cell)

x = torch.randn(100, 1, input_size) # random input length 100, batch_size = 1
hidden_state = rnn(x)

_ = plt.plot(hidden_state.detach().numpy().squeeze())

# %% [markdown]
# We expect the vanilla RNN won't be too useful because of vanishing gradients.
#
# We can improve with a slightly less vanilla RNN cell (still simpler than GRU or LSTM) where
# $$ f_t = \sigma( W_f [ x_t , h_{t-1} ]^T + \mu_f ) $$
# $$ g_t = \tanh( W_g [ x_t , h_{t-1} ]^T + \mu_g ) $$
# $$ h_t = f_t \cdot h_{t-1} + (1 - f_t) \cdot g_t $$

# %%
class MyLessVanillaRNNCell(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(MyLessVanillaRNNCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.linear_f = nn.Linear(input_size + hidden_size, hidden_size)
        self.mu_f = nn.Parameter(torch.randn(hidden_size))

        self.linear_g = nn.Linear(input_size + hidden_size, hidden_size)
        self.mu_g = nn.Parameter(torch.randn(hidden_size))

    def forward(self, x, h_in):
      combined = torch.cat((x, h_in), 1)
      f_t = torch.sigmoid(self.linear_f(combined) + self.mu_f)
      g_t = torch.tanh(self.linear_g(combined) + self.mu_g)
      h_out = f_t * h_in + (1 - f_t) * g_t
      return h_out

rnn_cell = MyLessVanillaRNNCell(input_size, hidden_size)
rnn = MyRNNLayer(rnn_cell)
output = rnn(x)
_ = plt.plot(output.detach().numpy().squeeze())

# %% [markdown]
# To make full regular RNN model we would also want to also calculate outputs as a function of the hidden states:

# %%
class BasicRNN(nn.Module):

    def __init__(self, rnn_layer, output_size):
        super(BasicRNN, self).__init__()
        self.rnn_layer = rnn_layer
        self.linear = nn.Linear(rnn_layer.hidden_size, output_size)

    def forward(self, x):
        h = self.rnn_layer(x)
        output = self.linear(h)
        return output

output_size = 3
rnn_cell = MyLessVanillaRNNCell(input_size, hidden_size)
rnn_layer = MyRNNLayer(rnn_cell)
model = BasicRNN(rnn_layer, output_size)
model(x).shape
# Out:
# torch.Size([100, 1, 3])

# %% [markdown]
# For our methylation data we'll initially consider each cell independently. The RNN input will be the methylated and unmethylated counts (two input features - channels if this were a CNN)

# %%
class MethModel(nn.Module):
    def __init__(self, rnn_layer, input_size = 2, output_size = 1):
        super(MethModel, self).__init__()
        self.hidden_size = rnn_layer.hidden_size
        self.embed = nn.Linear(input_size, rnn_layer.input_size) # the embed layer runs independently on each pair of meth/unmeth counts
        self.rnn_layer = rnn_layer
        self.linear = nn.Linear(self.hidden_size, output_size)

    def forward(self, meth, unmeth): # meth is seq x batch x cells
        batch_size = meth.shape[1]
        num_cells = meth.shape[2]
        meth = meth.view(meth.shape[0], batch_size * num_cells)
        unmeth = unmeth.view(unmeth.shape[0], batch_size * num_cells)
        x = torch.stack((meth,unmeth),2) # seq x (cells x batch) x channels(=meth and unmeth counts)
        x = self.embed(x) # seq x cells(=batch) x channels
        x = F.relu(x)
        h = self.rnn_layer(x)
        if isinstance(rnn_layer, nn.RNNBase): h = h[0] # torch RNN layers give h[0:t] and h[-1]
        output = self.linear(h)
        output = output.view(output.shape[0], batch_size, num_cells, output.shape[-1])
        output = output[:,:,:,0]
        return output

# %% [markdown]
# We'll be using the single cell methylation data again:

# %%
class CpgDataset(torch.utils.data.Dataset):

    def __init__(self, meth_counts, unmeth_counts, seq_len = 1000):
        super(CpgDataset, self).__init__()
        self.meth_counts = meth_counts
        self.unmeth_counts = unmeth_counts
        self.seq_len = seq_len

    def __getitem__(self, i):
        return(self.meth_counts[i*self.seq_len:(i+1)*self.seq_len].astype(np.float32),
               self.unmeth_counts[i*self.seq_len:(i+1)*self.seq_len].astype(np.float32))

    def __len__(self):
        return self.meth_counts.shape[0] // self.seq_len

# %% [markdown]
# We want to do one step ahead prediction, i.e.
# $ L = - \sum_{j=1}^J \sum_{t=1}^{T-1} \log Bin( M_{t+1,j} | M_{t+1,j} + U_{t+1,j}, p_{tj} ) $ where $p_{tj}$ is the output of the RNN at position $t$ and cell $j$.
#
# We write out the loss explicitly with log function(s):
#
# $$ Bin\left(n,p\right)=\frac{n!}{k!\left(n-k\right)!}p^{k}q^{\left(n-k\right)} $$
# $$ \log Bin\left(n,p\right) \propto k\log p+\left(n-k\right)\log q $$
#
# $$ L=-\sum_{j=1}^{J}\sum_{t=1}^{T-1}M_{t+1,j}\log\left(p_{tj}\right)+U_{t+1,j}\log\left(1-p_{tj}\right) $$
#
#
# Implement this

# %%
import timeit

def run_one_epoch(train_flag, dataloader, model, optimizer, device="cuda"):

    torch.set_grad_enabled(train_flag)
    model.train() if train_flag else model.eval()

    losses = []
    accuracies = []

    for meth,unmeth in dataloader:

        # DataLoader's automatic batching makes batch x seq x cells tensors,
        # For RNNs we want seq x batch x cells
        meth = meth.transpose(0,1).contiguous()
        unmeth = unmeth.transpose(0,1).contiguous()

        (meth, unmeth) = ( meth.to(device), unmeth.to(device) ) # transfer data to GPU

        # forward
        logodds = model(meth, unmeth) # the output is seq x batch x cells

        lo = logodds[:-1,:,:] # shift by one since we're doing one-step (i.e. one CpG) ahead prediction
        prob_methylated = torch.sigmoid(lo)

        # Calculate binomial loss

        batch_size = meth.shape[1];num_cells = meth.shape[2]

        loss=0
        for b in range(meth.shape[1]):
            loss -= torch.mean(torch.log(prob_methylated[:,b,:]) * meth[1:,b,:] + torch.log1p(-1*prob_methylated[:,b,:]) * unmeth[1:,b,:1])

        losses.append(loss.detach().cpu().numpy())

        if train_flag:
            loss.backward() # back propagation
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Gradient clipping
            optimizer.step()
            optimizer.zero_grad()

        # calculate accuracy
        meth_sum = meth[1:,:,:] + unmeth[1:,:,:]
        meth_rate = meth[1:,:,:] / meth_sum
        correct = ((meth_rate > .5) == (prob_methylated > .5))[meth_sum > 0]
        accuracy = torch.mean( correct.float() )

        accuracies.append(accuracy.detach().cpu().numpy())

    return( np.mean(losses), np.mean(accuracies) )

def train_loop(model,
               optimizer,
               train_dataloader,
               validation_dataloader,
               check_point_filename = '/content/drive/My Drive/scBSseq/rnn_checkpoint.pt',
               max_epochs = 100,
               patience = 10,
               device = "cuda"):

    train_accs = []
    val_accs = []
    patience_counter = patience
    best_val_loss = np.inf

    for epoch in range(max_epochs):
        start_time = timeit.default_timer()
        train_loss, train_acc = run_one_epoch(True, train_dataloader, model, optimizer, device)
        val_loss, val_acc = run_one_epoch(False, validation_dataloader, model, optimizer, device)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

        elapsed = float(timeit.default_timer() - start_time)
        print("Epoch %i took %.2fs. Train loss: %.4f acc: %.4f. Val loss: %.4f acc: %.4f. Patience left: %i" %
            (epoch+1, elapsed, train_loss, train_acc, val_loss, val_acc, patience_counter ))

        if val_loss < best_val_loss:
            torch.save(model.state_dict(), check_point_filename)
            best_val_loss = val_loss
            patience_counter = patience
        else:
            patience_counter -= 1
            if patience_counter <= 0:
                model.load_state_dict(torch.load(check_point_filename)) # recover the best model so far
                break

    return(train_accs, val_accs)

# %% [markdown]
# Let's train!

# %%
batch_size = 100
seq_len = 800 # tweaked from 1000 due to memory issues

training_cpg = chroms == "18"
train_dataset = CpgDataset(meth_mat[training_cpg,:], unmeth_mat[training_cpg,:], seq_len = seq_len)
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size = batch_size,
                                               num_workers = 0 ) # actually slower with more workers

val_cpg = chroms == "19"
val_dataset = CpgDataset(meth_mat[val_cpg,:], unmeth_mat[val_cpg,:], seq_len = seq_len)
validation_dataloader = torch.utils.data.DataLoader(val_dataset,
                                               batch_size = batch_size,
                                               num_workers = 0)

hidden_size = 10 # tweaked from 32 due to memory issues

rnn_cell = MyLessVanillaRNNCell(input_size = hidden_size, hidden_size = hidden_size)
rnn_layer = MyRNNLayer(rnn_cell)

model = MethModel(rnn_layer)

device = "cuda"
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), amsgrad=True)
torch.cuda.empty_cache()

train_accs, val_accs = train_loop(model,
                                optimizer,
                                train_dataloader,
                                validation_dataloader,
                                check_point_filename = '/content/drive/My Drive/scBSseq/rnn_checkpoint.pt',
                                device = device,
                                max_epochs = 30)

test_cpg = chroms == "17"
test_dataset = CpgDataset(meth_mat[test_cpg,:], unmeth_mat[test_cpg,:], seq_len = seq_len)
test_dataloader = torch.utils.data.DataLoader(test_dataset,
                                               batch_size = batch_size,
                                               num_workers = 0)

test_loss, test_acc = run_one_epoch(False, test_dataloader, model, optimizer, device)
print(test_acc)
# Out:
# Epoch 1 took 6.94s. Train loss: 30.1743 acc: 0.6510. Val loss: 25.2457 acc: 0.7306. Patience left: 10
# Epoch 2 took 6.70s. Train loss: 29.9909 acc: 0.6513. Val loss: 25.0577 acc: 0.7334. Patience left: 10
# Epoch 3 took 7.08s. Train loss: 29.8201 acc: 0.6515. Val loss: 24.8801 acc: 0.7358. Patience left: 10
# Epoch 4 took 6.75s. Train loss: 29.6596 acc: 0.6515. Val loss: 24.7121 acc: 0.7379. Patience left: 10
# Epoch 5 took 6.89s. Train loss: 29.5087 acc: 0.6515. Val loss: 24.5530 acc: 0.7389. Patience left: 10
# Epoch 6 took 6.78s. Train loss: 29.3667 acc: 0.6516. Val loss: 24.4020 acc: 0.7399. Patience left: 10
# Epoch 7 took 6.76s. Train loss: 29.2329 acc: 0.6517. Val loss: 24.2587 acc: 0.7405. Patience left: 10
# Epoch 8 took 6.92s. Train loss: 29.1068 acc: 0.6518. Val loss: 24.1226 acc: 0.7411. Patience left: 10
# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
import numpy as np
import timeit
import matplotlib.pyplot as plt

# Define the GRU layer
class MyGRULayer(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(MyGRULayer, self).__init__()
        self.gru = nn.GRU(input_size=input_size, hidden_size=hidden_size, batch_first=True)

    @property
    def hidden_size(self):
        return self.gru.hidden_size

    @property
    def input_size(self):
        return self.gru.input_size

    def forward(self, x):
        output, _ = self.gru(x)
        return output

# Define the LSTM layer
class MyLSTMLayer(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(MyLSTMLayer, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, batch_first=True)

    @property
    def hidden_size(self):
        return self.lstm.hidden_size

    @property
    def input_size(self):
        return self.lstm.input_size

    def forward(self, x):
        output, _ = self.lstm(x)
        return output


# Set up training and validation datasets
batch_size = 100
seq_len = 800

training_cpg = chroms == "18"
train_dataset = CpgDataset(meth_mat[training_cpg, :], unmeth_mat[training_cpg, :], seq_len=seq_len)
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=batch_size,
                                               num_workers=0)  # actually slower with more workers

val_cpg = chroms == "19"
val_dataset = CpgDataset(meth_mat[val_cpg, :], unmeth_mat[val_cpg, :], seq_len=seq_len)
validation_dataloader = torch.utils.data.DataLoader(val_dataset,
                                                    batch_size=batch_size,
                                                    num_workers=0)

# Define hidden size
hidden_size = 10

# Create models and optimizer
rnn_cell_vanilla = MyVanillaRNNCell(input_size=hidden_size, hidden_size=hidden_size)
rnn_layer_vanilla = MyRNNLayer(rnn_cell_vanilla)
model_vanilla = MethModel(rnn_layer_vanilla)
model_vanilla.to(device)
optimizer_vanilla = torch.optim.Adam(model_vanilla.parameters(), amsgrad=True)

rnn_cell_less_vanilla = MyLessVanillaRNNCell(input_size=hidden_size, hidden_size=hidden_size)
rnn_layer_less_vanilla = MyRNNLayer(rnn_cell_less_vanilla)
model_less_vanilla = MethModel(rnn_layer_less_vanilla)
model_less_vanilla.to(device)
optimizer_less_vanilla = torch.optim.Adam(model_less_vanilla.parameters(), amsgrad=True)

rnn_layer_gru = MyGRULayer(input_size=hidden_size, hidden_size=hidden_size)
model_gru = MethModel(rnn_layer_gru)
model_gru.to(device)
optimizer_gru = torch.optim.Adam(model_gru.parameters(), amsgrad=True)

rnn_layer_lstm = MyLSTMLayer(input_size=hidden_size, hidden_size=hidden_size)
model_lstm = MethModel(rnn_layer_lstm)
model_lstm.to(device)
optimizer_lstm = torch.optim.Adam(model_lstm.parameters(), amsgrad=True)

# Train the models
train_accs_vanilla, val_accs_vanilla = train_loop(model_vanilla,
                                                  optimizer_vanilla,
                                                  train_dataloader,
                                                  validation_dataloader,
                                                  check_point_filename='/content/drive/My Drive/scBSseq/rnn_checkpoint_vanilla.pt',
                                                  device=device,
                                                  max_epochs=30)

train_accs_less_vanilla, val_accs_less_vanilla = train_loop(model_less_vanilla,
                                                            optimizer_less_vanilla,
                                                            train_dataloader,
                                                            validation_dataloader,
                                                            check_point_filename='/content/drive/My Drive/scBSseq/rnn_checkpoint_less_vanilla.pt',
                                                            device=device,
                                                            max_epochs=30)

train_accs_gru, val_accs_gru = train_loop(model_gru,
                                          optimizer_gru,
                                          train_dataloader,
                                          validation_dataloader,
                                          check_point_filename='/content/drive/My Drive/scBSseq/rnn_checkpoint_gru.pt',
                                          device=device,
                                          max_epochs=30)

train_accs_lstm, val_accs_lstm = train_loop(model_lstm,
                                            optimizer_lstm,
                                            train_dataloader,
                                            validation_dataloader,
                                            check_point_filename='/content/drive/My Drive/scBSseq/rnn_checkpoint_lstm.pt',
                                            device=device,
                                            max_epochs=30)



# Plot the results
plt.plot(train_accs_vanilla, "--", label="Vanilla RNN Train", color="blue")
plt.plot(val_accs_vanilla, label="Vanilla RNN Validation", color="blue")
plt.plot(train_accs_less_vanilla, "--", label="Less Vanilla RNN Train", color="green")
plt.plot(val_accs_less_vanilla, label="Less Vanilla RNN Validation", color="green")
plt.plot(train_accs_gru, "--", label="GRU Train", color="red")
plt.plot(val_accs_gru, label="GRU Validation", color="red")
plt.plot(train_accs_lstm, "--", label="LSTM Train", color="orange")
plt.plot(val_accs_lstm, label="LSTM Validation", color="orange")


plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Epoch 1 took 6.72s. Train loss: 31.2073 acc: 0.6515. Val loss: 26.2040 acc: 0.7407. Patience left: 10
# Epoch 2 took 7.06s. Train loss: 31.0785 acc: 0.6515. Val loss: 26.0773 acc: 0.7407. Patience left: 10
# Epoch 3 took 7.17s. Train loss: 30.9587 acc: 0.6515. Val loss: 25.9563 acc: 0.7407. Patience left: 10
# Epoch 4 took 6.11s. Train loss: 30.8444 acc: 0.6515. Val loss: 25.8400 acc: 0.7407. Patience left: 10
# Epoch 5 took 5.99s. Train loss: 30.7349 acc: 0.6515. Val loss: 25.7279 acc: 0.7407. Patience left: 10
# Epoch 6 took 5.91s. Train loss: 30.6296 acc: 0.6515. Val loss: 25.6196 acc: 0.7407. Patience left: 10
# Epoch 7 took 5.83s. Train loss: 30.5281 acc: 0.6515. Val loss: 25.5148 acc: 0.7407. Patience left: 10
# Epoch 8 took 6.00s. Train loss: 30.4301 acc: 0.6515. Val loss: 25.4132 acc: 0.7407. Patience left: 10
# Epoch 9 took 5.88s. Train loss: 30.3353 acc: 0.6515. Val loss: 25.3146 acc: 0.7407. Patience left: 10
# Epoch 10 took 5.95s. Train loss: 30.2435 acc: 0.6515. Val loss: 25.2187 acc: 0.7407. Patience left: 10
# Epoch 11 took 5.93s. Train loss: 30.1544 acc: 0.6515. Val loss: 25.1255 acc: 0.7407. Patience left: 10
# Epoch 12 took 5.84s. Train loss: 30.0679 acc: 0.6515. Val loss: 25.0346 acc: 0.7407. Patience left: 10
# Epoch 13 took 6.00s. Train loss: 29.9836 acc: 0.6515. Val loss: 24.9457 acc: 0.7407. Patience left: 10
# Epoch 14 took 5.85s. Train loss: 29.9011 acc: 0.6515. Val loss: 24.8590 acc: 0.7407. Patience left: 10
# Epoch 15 took 5.81s. Train loss: 29.8207 acc: 0.6515. Val loss: 24.7742 acc: 0.7407. Patience left: 10
# Epoch 16 took 6.00s. Train loss: 29.7421 acc: 0.6515. Val loss: 24.6912 acc: 0.7407. Patience left: 10
# Epoch 17 took 6.17s. Train loss: 29.6653 acc: 0.6515. Val loss: 24.6101 acc: 0.7407. Patience left: 10
# Epoch 18 took 5.96s. Train loss: 29.5901 acc: 0.6515. Val loss: 24.5305 acc: 0.7407. Patience left: 10
# Epoch 27 took 0.47s. Train loss: 29.5418 acc: 0.6538. Val loss: 24.7316 acc: 0.7413. Patience left: 10
# Epoch 28 took 0.47s. Train loss: 29.4282 acc: 0.6536. Val loss: 24.6145 acc: 0.7419. Patience left: 10
# Epoch 29 took 0.47s. Train loss: 29.3164 acc: 0.6534. Val loss: 24.4991 acc: 0.7419. Patience left: 10
# Epoch 30 took 0.47s. Train loss: 29.2066 acc: 0.6533. Val loss: 24.3855 acc: 0.7418. Patience left: 10

# %% [markdown]
# Three models—Vanilla RNN, GRU, and LSTM—showed a stable accuracy plateau at 0.75 on the train and validation set, indicating convergence to a common performance level. I noticed that the Vanilla RNN quickly reached and maintained the plateau, suggesting efficient learning of relevant sequencing patterns, though its simplicity may limit capturing long-term dependencies compared to GRU and LSTM. It is interesting to note that the observed bump where the GRU and LSTM accuracies briefly peaked above the final plateau value before dropping could be attributed to the learning rate schedule or optimization dynamics which might have caused a momentary overshoot in the parameter space. We can also consider the presence of stochastic elements in the cell data or mini-batch sampling which can introduce variability during training.

# %% [markdown]
# ## Sharing information across cells
#
# Next we'll try to learn an RNN that shares information across cells like the HMM did and more like DeepCpG. Now our input is the methylated and unmethylated counts for all the cells. We first embed each cell's counts as before, and but then run the RNN on the concatenation of all the cells' embeddings (which we get using the view function).

# %%
class MethJointModel(nn.Module):
    def __init__(self, rnn_layer, input_size, num_cells, embedding_size):
        super(MethJointModel, self).__init__()
        self.embed = nn.Linear(input_size, embedding_size)
        self.rnn_layer = rnn_layer
        self.linear = nn.Linear(rnn_layer.hidden_size, num_cells)

    def forward(self, meth, unmeth):
        x = torch.stack((meth,unmeth),3) # seq x batch x cells x channels(=meth and unmeth counts)
        x = self.embed(x) # seq x batch x cells x hidden_size
        x = x.view(x.shape[0], x.shape[1], x.shape[2] * x.shape[3]) # seq x batch x (cells x hidden_size)
        x = F.relu(x)
        h = self.rnn_layer(x)
        if isinstance(rnn_layer, nn.RNNBase): h = h[0] # torch RNN layers give h[0:t] and h[-1]
        output = self.linear(h)
        return output

# %%
hidden_size = 32
num_cells = meth_mat.shape[1]
embedding_size = 3

rnn_layer = nn.LSTM(input_size = num_cells * embedding_size, hidden_size = hidden_size)

model = MethJointModel(rnn_layer, input_size = 2, num_cells = num_cells, embedding_size = embedding_size)

device = "cuda"
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), amsgrad=True)

train_accs, val_accs = train_loop(model,
                                optimizer,
                                train_dataloader,
                                validation_dataloader,
                                check_point_filename = '/content/drive/My Drive/scBSseq/rnn_checkpoint.pt',
                                device = device,
                                max_epochs = 100) # high dimensional: takes longer to converge

test_loss, test_acc = run_one_epoch(False, test_dataloader, model, optimizer, device)
print(test_acc)
# Out:
# Epoch 1 took 0.34s. Train loss: 31.8432 acc: 0.4888. Val loss: 26.8041 acc: 0.5375. Patience left: 10
# Epoch 2 took 0.44s. Train loss: 31.4859 acc: 0.5260. Val loss: 26.4920 acc: 0.5766. Patience left: 10
# Epoch 3 took 0.38s. Train loss: 31.1617 acc: 0.5596. Val loss: 26.1829 acc: 0.6005. Patience left: 10
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %% [markdown]
# Now we vary the number of RNN layers to assess its impact on performance.

# %%
import copy

def train_with_restart(model, optimizer, train_dataloader, validation_dataloader, device, max_epochs=100, restarts=3):
    best_model_state_dict = None
    best_val_acc = 0.0

    for restart in range(restarts):
        print(f"Restart {restart + 1}/{restarts}")

        current_model = copy.deepcopy(model)
        current_model.to(device)

        current_optimizer = torch.optim.Adam(current_model.parameters(), amsgrad=True)

        train_accs, val_accs = train_loop(current_model,
                                          current_optimizer,
                                          train_dataloader,
                                          validation_dataloader,
                                          check_point_filename = '/content/drive/My Drive/scBSseq/rnn_checkpoint.pt',
                                          device=device,
                                          max_epochs=max_epochs)

        final_val_acc = val_accs[-1]

        print(f"Final Validation Accuracy (Restart {restart + 1}): {final_val_acc}")

        if final_val_acc > best_val_acc:
            best_val_acc = final_val_acc
            best_model_state_dict = copy.deepcopy(current_model.state_dict())

    model.load_state_dict(best_model_state_dict)
    return best_val_acc

# Define the number of layers to experiment with
num_layers_list = [1, 2, 3]

# Initialize lists to store results
test_accs_list = []

# Experiment with different numbers of layers
for num_layers in num_layers_list:
    rnn_layer = nn.LSTM(input_size=num_cells * embedding_size, hidden_size=hidden_size, num_layers=num_layers)
    model = MethJointModel(rnn_layer, input_size=2, num_cells=num_cells, embedding_size=embedding_size)
    model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), amsgrad=True)

    print(f"\nTraining with {num_layers} RNN layers")
    test_acc = train_with_restart(model,
                                  optimizer,
                                  train_dataloader,
                                  validation_dataloader,
                                  device=device,
                                  max_epochs=30,
                                  restarts=3)

    test_accs_list.append(test_acc)

# Plot the results
plt.plot(num_layers_list, test_accs_list, marker='o')
plt.xlabel("Number of RNN Layers")
plt.ylabel("Test Accuracy")
plt.title("Effect of Number of RNN Layers on Test Accuracy")
plt.show()
# Out:
# Training with 1 RNN layers
# Restart 1/3
# Epoch 1 took 0.43s. Train loss: 31.4029 acc: 0.5516. Val loss: 26.5745 acc: 0.5730. Patience left: 10
# Epoch 2 took 0.56s. Train loss: 31.2509 acc: 0.5654. Val loss: 26.4438 acc: 0.5936. Patience left: 10
# Epoch 3 took 0.68s. Train loss: 31.1074 acc: 0.5818. Val loss: 26.3133 acc: 0.6140. Patience left: 10
# Epoch 4 took 0.60s. Train loss: 30.9626 acc: 0.5977. Val loss: 26.1769 acc: 0.6304. Patience left: 10
# Epoch 5 took 0.62s. Train loss: 30.8101 acc: 0.6113. Val loss: 26.0289 acc: 0.6434. Patience left: 10
# Epoch 6 took 0.62s. Train loss: 30.6448 acc: 0.6222. Val loss: 25.8649 acc: 0.6535. Patience left: 10
# Epoch 7 took 0.62s. Train loss: 30.4632 acc: 0.6322. Val loss: 25.6814 acc: 0.6652. Patience left: 10
# Epoch 8 took 0.52s. Train loss: 30.2636 acc: 0.6447. Val loss: 25.4771 acc: 0.6744. Patience left: 10
# Epoch 9 took 0.64s. Train loss: 30.0458 acc: 0.6547. Val loss: 25.2529 acc: 0.6819. Patience left: 10
# Epoch 10 took 0.66s. Train loss: 29.8114 acc: 0.6603. Val loss: 25.0100 acc: 0.6865. Patience left: 10
# Epoch 11 took 0.33s. Train loss: 29.5125 acc: 0.6456. Val loss: 24.3885 acc: 0.7114. Patience left: 10
# Epoch 12 took 0.32s. Train loss: 29.0177 acc: 0.6414. Val loss: 23.8926 acc: 0.7119. Patience left: 10
# Epoch 13 took 0.32s. Train loss: 28.5477 acc: 0.6414. Val loss: 23.4320 acc: 0.7178. Patience left: 10
# Epoch 14 took 0.32s. Train loss: 28.0939 acc: 0.6433. Val loss: 22.9734 acc: 0.7187. Patience left: 10
# Epoch 15 took 0.33s. Train loss: 27.6007 acc: 0.6451. Val loss: 22.4877 acc: 0.7311. Patience left: 10
# Epoch 16 took 0.33s. Train loss: 27.0447 acc: 0.6555. Val loss: 21.9979 acc: 0.7350. Patience left: 10
# Epoch 17 took 0.32s. Train loss: 26.4902 acc: 0.6627. Val loss: 21.5678 acc: 0.7514. Patience left: 10
# Epoch 18 took 0.33s. Train loss: 26.0284 acc: 0.6789. Val loss: 21.2076 acc: 0.7601. Patience left: 10
# Epoch 19 took 0.32s. Train loss: 25.6498 acc: 0.6932. Val loss: 20.8685 acc: 0.7735. Patience left: 10
# Epoch 20 took 0.32s. Train loss: 25.2903 acc: 0.7043. Val loss: 20.5152 acc: 0.7765. Patience left: 10
# Epoch 21 took 0.37s. Train loss: 24.9145 acc: 0.7099. Val loss: 20.1657 acc: 0.7772. Patience left: 10
# Epoch 22 took 0.37s. Train loss: 24.5496 acc: 0.7116. Val loss: 19.8389 acc: 0.7787. Patience left: 10
# Epoch 23 took 0.37s. Train loss: 24.2126 acc: 0.7141. Val loss: 19.5397 acc: 0.7814. Patience left: 10
# Epoch 24 took 0.37s. Train loss: 23.9034 acc: 0.7191. Val loss: 19.2588 acc: 0.7843. Patience left: 10
# Epoch 25 took 0.37s. Train loss: 23.6077 acc: 0.7231. Val loss: 18.9846 acc: 0.7866. Patience left: 10
# Epoch 26 took 0.37s. Train loss: 23.3121 acc: 0.7262. Val loss: 18.7173 acc: 0.7890. Patience left: 10
# Epoch 27 took 0.37s. Train loss: 23.0233 acc: 0.7292. Val loss: 18.4736 acc: 0.7918. Patience left: 10
# Epoch 28 took 0.37s. Train loss: 22.7609 acc: 0.7322. Val loss: 18.2663 acc: 0.7926. Patience left: 10
# Epoch 29 took 0.37s. Train loss: 22.5336 acc: 0.7324. Val loss: 18.0671 acc: 0.7931. Patience left: 10
# Epoch 30 took 0.39s. Train loss: 22.3131 acc: 0.7330. Val loss: 17.8595 acc: 0.7944. Patience left: 10
# Final Validation Accuracy (Restart 3): 0.7944424152374268

# %% [markdown]
# The relatively high accuracy with a single RNN layer suggests that the model is able to capture the temporal dependencies and information across cells effectively. The single layer might be sufficient to learn the global patterns in the concatenated sequence of methylated and unmethylated counts. The drop in accuracy with the addition of a second layer indicates that, in this specific context, increasing the model's depth did not contribute positively to the overall performance. It's possible that the added complexity led to difficulties in learning relevant information across cells or introduced challenges related to overfitting. The highest accuracy achieved with three layers suggests that, in this particular scenario, a deeper network may be beneficial but it is difficult to say that's true overall. The increased depth may allow the model to capture more intricate relationships and dependencies across cells, needed for tasks involving methylated and unmethylated counts.
